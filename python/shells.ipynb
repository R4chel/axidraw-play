# %%
import drawSvg as draw
import random
import math

# %%
xMax= 250
yMax = 250

# %%
class Circle:
    def __init__(self, x,y,r):
        self.x = x
        self.y = y
        self.r = r
    
    def toSvg(self):
        return draw.Circle(self.x,self.y,self.r, stroke_width=1,stroke='black', fill='none')
    
    def halfCircle(self):
        return draw.Arc(self.x,self.y,self.r, 0, 180, stroke_width=1,stroke='black', fill='none')

# %%
r = 25
offset=False
circles = []
for y in range(-1*yMax, yMax, r):
    initial_x = -1*xMax - (r if offset else 0)
    for x in range(initial_x, xMax+r, r*2):
        circles.append(Circle(x,y,r))
    offset = not offset

# %%
len(circles)
# Out:
# 220

# %%
d = draw.Drawing(xMax*2, yMax*2, origin='center')
for c in circles:
    d.append(c.halfCircle())

# %%
# Display in Jupyter notebook
d.rasterize()  # Display as PNG
d  # Display as SVG

# %%
d.saveSvg('shells.svg')
